# %% [markdown]
# # presentation (tips):

# %%
#let s start with taking a look at our data: 
import pandas as pd
data=pd.read_csv("C:/file/tips.csv",sep=",")
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#install seaborn
# !pip install seaborn

# %%
#importing our libraries:
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# %%
#i m sure it s wrong at least i got the same figure :')  :


sns.set_style('darkgrid')

x = ['total_bill', 'tip', 'size']
y = [20, 3, 2]

sns.barplot(x, y)
plt.show()
# Out:
# C:\Users\nourain\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#moving to the scatter plot
sns.scatterplot(x="total_bill", y="tip", data=data)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# the dots in the scatter plot are moving upwards and to the right, it indicates a positive correlation.

# %%
#the boxplot 
new_data=data.drop(["sex","size","time","smoker","day"],axis=1)
scaler=StandardScaler()
sns.boxplot(data=new_data)
# Out:
# <AxesSubplot:>

# %% [markdown]
# the two boxplots are obviously not standardized:

# %%
#let s fix the problem using the 
new_data=data.drop(["sex","size","time","smoker","day"],axis=1)
scaler=StandardScaler()
new_data["total_bill"]=scaler.fit_transform(new_data[["total_bill"]].values)
new_data["tip"]=scaler.fit_transform(new_data[["tip"]].values)
sns.boxplot(data=new_data)
# Out:
# <AxesSubplot:>

# %%
sns.histplot(data['total_bill'],bins=25)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %% [markdown]
# this following plot gives the distribution of totall bills :
# *the minimum total bill is around 2 USD
# *the maximum total bill is around 30 USD

# %%
sns.barplot(x="time",y="total_bill",hue="day",data=data)
# Out:
# <AxesSubplot:xlabel='time', ylabel='total_bill'>

# %% [markdown]
# the totall bill is higher in sunday and espacially inn dinner  and it s lower in friday while lunch

# %%
sns.barplot(x="time",y="total_bill",data=data,hue="smoker")
# Out:
# <AxesSubplot:xlabel='time', ylabel='total_bill'>

# %% [markdown]
# *the smokers seem to pay a little bit more than the non-smokers both in Dinner and Lunch

# %%
sns.histplot(x="size",data=data,bins=12)
# Out:
# <AxesSubplot:xlabel='size', ylabel='Count'>

# %% [markdown]
# from this plot we can conclude that customers prefer the size 2

# %%
data.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# whatever is closer to the lighter color is correlated with each other : for example the tip and the total bill are highly correlated

# %%
new_data=data.drop(["sex","size","time","smoker","day"],axis=1)
new_data.plot()
# Out:
# <AxesSubplot:>
