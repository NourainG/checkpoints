# %% [markdown]
# 1- Read your Titanic dataset as usual: Create a training set and a testing set then apply decision tree.

# %%
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score
import pandas as pd
df = pd.read_csv("C:/file/titanic-passengers.csv",sep=";")

# %%
def preprocess_data(new_data):
    df['Age'].fillna(df['Age'].mean(),inplace=True)
    df.replace({'Sex':{'male': 1,'female':0}},inplace=True)
    df['Cabin']=df.Cabin.fillna('G6')
    df.replace({'Survived':{'Yes': 1,'No':0}},inplace=True)
    return df
data=preprocess_data(df)

# %%
x=df[["Age","Sex"]]
y=df["Survived"]

x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.25,random_state=42)
treee= DecisionTreeClassifier()

treee.fit(x_train,y_train)

y_pred=treee.predict(x_test)
accuracy = accuracy_score(y_test, y_pred)*100
print("score={:.4f}%".format(accuracy))
# Out:
# score=74.4395%

# %% [markdown]
# 4-Calculate the new accuracy and compare it with the previous results.

# %%
from sklearn import tree
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt
ts= tree.DecisionTreeClassifier()
ts=ts.fit(x,y)
plt.figure()
tree.plot_tree(ts)
plt.show()

# %% [markdown]
# 3- Change the decision tree parameters(at least two parameters).

# %%
from sklearn import tree
ts= tree.DecisionTreeClassifier(max_depth=2, min_samples_leaf=4)
ts= ts.fit(x,y)
plt.figure()
tree.plot_tree(ts)
plt.show()

# %% [markdown]
# 4-Calculate the new accuracy and compare it with the previous results

# %%
from sklearn.metrics import precision_score

# %%
y_pred= ts.predict(x)
new_accuracy = accuracy_score(y,y_pred)*100
print ("accuracy{}".format(accuracy))
if (accuracy>new_accuracy):
    print(f"accuracy has a better performance {accuracy} ")
else:
    print(f"the new accuracy has a better performance {new_accuracy}")
# Out:
# accuracy74.43946188340807
# the new accuracy has a better performance 79.57351290684625

# %% [markdown]
# 5- Use a random forest then change the number of estimators.

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn import metrics
ts=RandomForestClassifier(n_estimators=10)  #Creating a random forest with 100 decision trees
ts.fit(x_train, y_train) #Training our model
y_pred=ts.predict(x_test)  #testing our model
print("Accuracy:", metrics.accuracy_score(y_test, y_pred)*100)  #Measuring the accuracy of our model
# Out:
# Accuracy: 73.09417040358744

# %% [markdown]
# 6- Calculate the new accuracy and compare it with the previous result.

# %%
ts=ts=RandomForestClassifier(n_estimators=1000)
ts.fit(x_train, y_train) #Training our model
y_pred=ts.predict(x_test)  #testing our model
print("Accuracy:", metrics.accuracy_score(y_test, y_pred)*100)  #Measuring the accuracy of our model
# Out:
# Accuracy: 76.68161434977578
